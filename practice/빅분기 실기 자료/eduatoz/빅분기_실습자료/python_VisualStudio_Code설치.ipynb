# %% [markdown]
# ### 4.파이썬 환경
# - 파이썬 설치 : https://www.python.org/downloads/  (python 3.7 이상의 버전 사용)
#     - 설치 첫 화면에서 'PATH'에 등록을 반드시 선택하세요.
#     - python 3.10은 아직 사용하지 마세요 ^^'
#
# - 주피터 노트북(Ipython) : https://jupyter.org/install.html
# - Visual Studio Code(Cpython) : https://code.visualstudio.com/download  (여기서 user installer  windows 64)
#     - https://docs.microsoft.com/ko-kr/learn/modules/python-install-vscode/

# %%
주피터 노트북 / 주피터 랩

# %% [markdown]
# #### 4-1.python 설치

# %% [markdown]
# 1) 하단의 Add Python 3.9 to PATH를 선택 후, 상단의 Customize installation 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2) 다음 화면에서는 그대로 Next를 선택합니다.

# %% [markdown]
# 3) Customize install location을 아래와 같이 변경하고 Install 버튼을 클릭합니다.

# %%
C:\Python\Python39_64

# %% [markdown]
# 4) 설치가 종료되면 Close를 클릭합니다.

# %% [markdown]
# #### 4-2. 설치 확인

# %%
1) Windows에서 cmd를 검색하여 실행합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
2) 명렬 프롬프트에서 아래와 같이 python --version 을 실행해 Python 버전이 올바르게 출력되는지 확인합니다.
만일 올바르게 출력되지 않는다면, PATH 등록이 되지 않은 것입니다. 
(다시 설치하시면서 PATH를 선택하시거나, PATH를 직접 수정해야 합니다.)

# %%
3) 필요한 라이브러리를 설치합니다. 

pip install numpy pandas openpyxl xlrd xlwt matplotlib seaborn

# %% [markdown]
# #### 4-3.Visual Studio Code - python 설정

# %%
Extensions에서 python으로 검색하여 설치

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
File 메뉴를 사용하여 Open Folder (사용할 Folder 지정) 또는 Add Folder to Workspace (여러 개의 Folder 사용시 Workspace에 Folder 추가)를 사용하여 
폴더를 지정함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Folder 에서 마우스 오른쪽 버튼을 클릭해 'New File' 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
파일 이름 입력 (확장자를 .py 로 지정)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
아래의 코드를 입력 후, [Ctrl] + F5로 실행
import sys
print(sys.version)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
만일, python 버전이 원하는 것이 아니라면 다음을 사용하여 변경할 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)
